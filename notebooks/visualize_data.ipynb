# %% [markdown]
# # Notebook para visualização dos dados brutos escolhidos inicialmente

# %% [markdown]
# ## Importação das Bibliotecas

# %%
import pandas as pd
import zipfile
import os

# %% [markdown]
# ## Visualização dos dados

# %%
PATH_ARQUIVO_ZIP = '../data/raw/dados_obitos_sim_2006_2017.zip'

# %%
# Extração do zip do arquivo bruto
if os.path.exists(PATH_ARQUIVO_ZIP):
    with zipfile.ZipFile(PATH_ARQUIVO_ZIP, 'r') as zip_ref:
        zip_ref.extractall('../data/raw/')
else:
    print(f'Arquivo {PATH_ARQUIVO_ZIP} não existe. Talvez você esqueceu de executar um dvc pull ...')

# %%
# Após extrair o zip, pode-se abrir o .csv com o pandas
df = pd.read_csv('../data/raw/sim_2006_2017.csv')
df
# Out:
# <ipython-input-4-f2561e5af0f6>:2: DtypeWarning: Columns (5,25,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/raw/sim_2006_2017.csv')
#          ACIDTRAB  ASSISTMED  ATESTANTE CAUSABAS CAUSABAS_O CIRCOBITO  \
# 0             NaN        NaN        2.0     R092       I469       NaN
# 1             NaN        NaN        5.0      R98        R98       NaN
# 2             NaN        1.0        1.0     R092       R092       NaN
# 3             NaN        1.0        4.0      R99        R99       NaN
# 4             NaN        NaN        NaN      R98        R98       NaN
# ...           ...        ...        ...      ...        ...       ...
# 3237588       NaN        NaN        2.0     R960       R960       NaN
# 3237589       NaN        NaN        2.0      R99        R99       NaN
# 3237590       NaN        1.0        5.0     J189       J189       NaN
# 3237591       NaN        1.0        1.0     J189       J189       NaN
# 3237592       NaN        2.0        3.0      R95        R95       NaN
#
#          CIRURGIA   CODESTAB        CODINST  CODMUNOCOR  ...      OCUP  \
# 0             NaN        NaN  MSP3519500001      351950  ...  999993.0
# 1             2.0        NaN  MSP3524900001      352490  ...  214305.0
# 2             2.0        NaN  MSP3532200001      353220  ...  514105.0
# 3             2.0        NaN  MSP3543100181      354310  ...  214305.0
# 4             2.0        NaN  MSP3532200001      353220  ...       NaN
# ...           ...        ...            ...         ...  ...       ...
# 3237588       NaN        NaN  MSP3537600001      353760  ...       NaN
# 3237589       NaN        NaN  MSP3537600001      353760  ...  999993.0
# 3237590       NaN  2746832.0  MSP3549950001      354995  ...  999993.0
# 3237591       NaN        NaN  MSP3541600001      354160  ...  999993.0
# 3237592       NaN        NaN  MSP3504500001      350750  ...       NaN
#
#           OCUPMAE  PARTO    PESO  QTDFILMORT  QTDFILVIVO  RACACOR  SEXO  \
# 0             NaN    NaN     NaN         NaN         NaN      1.0     1
# 1             NaN    NaN     NaN         NaN         NaN      NaN     1
# 2             NaN    NaN     NaN         NaN         NaN      1.0     2
# 3             NaN    NaN     NaN         NaN         NaN      1.0     1
# 4             NaN    NaN     NaN         NaN         NaN      1.0     2
# ...           ...    ...     ...         ...         ...      ...   ...
# 3237588       NaN    NaN     NaN         NaN         NaN      1.0     1
# 3237589       NaN    NaN     NaN         NaN         NaN      4.0     1
# 3237590       NaN    NaN     NaN         NaN         NaN      1.0     1
# 3237591       NaN    NaN     NaN         NaN         NaN      1.0     1
# 3237592  513205.0    1.0  2975.0         0.0         2.0      1.0     2
#
#          TIPOBITO  TPPOS
# 0               2      N
# 1               2      N
# 2               2      S
# 3               2      N
# 4               2      S
# ...           ...    ...
# 3237588         2    NaN
# 3237589         2    NaN
# 3237590         2      N
# 3237591         2      N
# 3237592         2      N
#
# [3237593 rows x 51 columns]
